# %%
import tweepy                   
import json
import pandas as pd
import csv
from datetime import date
from datetime import datetime
import time
import matplotlib.pyplot as plt

# %%
path = "C://Users//Happy//Desktop//Computer Science//Projects//Native//"
credentials = json.loads(open(path + 'twitter_credentials.json').read())  

consumer_key = credentials['CONSUMER_KEY']
consumer_secret = credentials['CONSUMER_SECRET']
access_token = credentials['ACCESS_TOKEN']
access_token_secret = credentials['ACCESS_SECRET']

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

#api = tweepy.API(auth)
api = tweepy.API(auth)

# %%
tweets = []

def username_tweets_to_csv(username,count):
    try:      
        # Creation of query method using parameters
        tweets = tweepy.Cursor(api.user_timeline,id=username).items(count)

        # Pulling information from tweets iterable object
        tweets_list = [[tweet.created_at, tweet.id, tweet.text] for tweet in tweets]

        # Creation of dataframe from tweets list
        # Add or remove columns as you remove tweet information
        tweets_df = pd.DataFrame(tweets_list,columns=['Datetime', 'Tweet Id', 'Text'])

        # Converting dataframe to CSV 
        tweets_df.to_csv('{}-tweets.csv'.format(username), sep=',', index = False)

    except BaseException as e:
          print('failed on_status,',str(e))
          time.sleep(3)

# %%
text_query = 'brightfarms'
max_tweets = 150
date_since = "2010-01-01"
sid = 1328500778395463681
 
# Creation of query method using parameters
tweets = tweepy.Cursor(api.search,q=text_query,max_id=sid).items(max_tweets)
 
# Pulling information from tweets iterable object
# Add or remove tweet information you want in the below list comprehension
tweets_list = [[tweet.text, tweet.created_at, tweet.id_str, tweet.user.name, 
                tweet.user.screen_name, tweet.user.id_str, tweet.user.location, 
                tweet.user.url, tweet.user.description, tweet.user.verified, tweet.user.followers_count, 
                tweet.user.friends_count, tweet.user.favourites_count, tweet.user.statuses_count, tweet.user.listed_count, 
                tweet.user.created_at, tweet.user.profile_image_url_https, tweet.user.default_profile, tweet.user.default_profile_image] for tweet in tweets]

# Creation of dataframe from tweets_list
# Add or remove columns as you remove tweet information
tweets_df3 = pd.DataFrame(tweets_list,columns=['Tweet Text', 'Tweet Datetime', 'Tweet Id', 'Twitter Username', 'Twitter @ name',
                                             'Twitter User Id', 'Twitter User Location', 'URL in Bio', 'Twitter Bio',
                                             'User Verified Status', 'Users Following Count',
                                             'Number users this account is following', 'Users Number of Likes', 'Users Tweet Count',
                                             'Lists Containing User', 'Account Created Time', 'Profile Image URL',
                                             'User Default Profile', 'User Default Profile Image'])

# %%
tweets_df2
# Out:
#                                            Tweet Text      Tweet Datetime  \
# 0   RT @SuperbCrew_com: BrightFarms Secures More T... 2020-11-18 12:05:56
# 1   RT @TechCompanyNews: BrightFarms Secures More ... 2020-11-18 12:05:45
# 2   RT @SuperbCrew_com: BrightFarms Secures More T... 2020-11-18 12:04:53
# 3   RT @TechCompanyNews: BrightFarms Secures More ... 2020-11-18 12:04:28
# 4   RT @TechCompanyNews: BrightFarms Secures More ... 2020-11-18 12:02:46
# 5   RT @SuperbCrew_com: BrightFarms Secures More T... 2020-11-18 12:02:20
# 6   RT @SuperbCrew_com: BrightFarms Secures More T... 2020-11-18 12:01:32
# 7   RT @TechCompanyNews: BrightFarms Secures More ... 2020-11-18 11:24:09
# 8   RT @SuperbCrew_com: BrightFarms Secures More T... 2020-11-18 10:34:43
# 9   RT @TechCompanyNews: BrightFarms Secures More ... 2020-11-18 10:34:34
# 10  RT @SuperbCrew_com: BrightFarms Secures More T... 2020-11-18 10:33:49
# 11  RT @TechCompanyNews: BrightFarms Secures More ... 2020-11-18 10:33:16
# 12  Deal alert! Bridgepoint is pleased to announce... 2020-11-17 17:10:21
# 4                      79                                     209
# 5                      79                                     209
# 6                      76                                     252
# 7                      76                                     252
# 8                      78                                     229
# 9                      78                                     229
# 10                     63                                     142
# 11                     63                                     142
# 12                    267                                     500
# 13                  28536                                   18857
# 14                  81101                                   53099
# 15                    713                                    1559
# 16                   2074                                    1320
# 17                    713                                    1559
#
#     Users Number of Likes  Users Tweet Count  Lists Containing User  \
# 0                    9106               9120                      2
# 1                    9106               9120                      2
# 2                   11502              11499                      3
# 3                   11502              11499                      3
# 4                   11530              11536                      4
# 5                   11530              11536                      4
# 6                   11583              11593                      3
# 7                   11583              11593                      3
# 8                    9108               9110                      2
# 9                    9108               9110                      2
# 10                   9053               9062                      2
# 11                   9053               9062                      2
# 12                    167                717                     10
# 13                  11677              18946                    236
# 14                  36519              28100                   1944
# 15                  47156             101195                     49
# 16                   7548               3714                    127
# 17                  47156             101195                     49
#
#    Account Created Time                                  Profile Image URL  \
# 0   2019-12-02 14:55:00  https://pbs.twimg.com/profile_images/120151536...
# 1   2019-12-02 14:55:00  https://pbs.twimg.com/profile_images/120151536...
# 2   2019-09-07 10:18:07  https://pbs.twimg.com/profile_images/117028217...
# 3   2019-09-07 10:18:07  https://pbs.twimg.com/profile_images/117028217...
# 4   2019-09-04 10:58:00  https://pbs.twimg.com/profile_images/117063636...
# 5   2019-09-04 10:58:00  https://pbs.twimg.com/profile_images/117063636...
# 6   2019-09-04 10:52:22  https://pbs.twimg.com/profile_images/116920157...
# 7   2019-09-04 10:52:22  https://pbs.twimg.com/profile_images/116920157...
# 8   2019-12-02 15:08:12  https://pbs.twimg.com/profile_images/120151878...
# 9   2019-12-02 15:08:12  https://pbs.twimg.com/profile_images/120151878...
# 10  2019-12-02 15:01:53  https://pbs.twimg.com/profile_images/120151798...
# 11  2019-12-02 15:01:53  https://pbs.twimg.com/profile_images/120151798...
# 12  2012-10-17 18:28:21  https://pbs.twimg.com/profile_images/104935345...
# 13  2016-11-25 14:16:19  https://pbs.twimg.com/profile_images/808761577...
# 14  2013-12-16 12:12:11  https://pbs.twimg.com/profile_images/484367594...
# 15  2011-04-04 15:31:34  https://pbs.twimg.com/profile_images/128815390...
# 16  2009-03-23 16:18:55  https://pbs.twimg.com/profile_images/673934174...
# 17  2011-04-04 15:31:34  https://pbs.twimg.com/profile_images/128815390...
#
#     User Default Profile  User Default Profile Image
# 0                   True                       False
# 1                   True                       False
# 2                   True                       False
# 3                   True                       False
# 4                   True                       False
# 5                   True                       False
# 6                   True                       False
# 7                   True                       False
# 8                   True                       False
# 9                   True                       False
# 10                  True                       False
# 11                  True                       False
# 12                 False                       False
# 13                  True                       False
# 14                 False                       False
# 15                 False                       False
# 16                 False                       False
# 17                 False                       False

# %%
tweets_df3
# Out:
#                                           Tweet Text      Tweet Datetime  \
# 0  @azhandkc @KCStar I never heard what happened ... 2020-11-17 00:50:42
#
#               Tweet Id Twitter Username Twitter @ name Twitter User Id  \
# 0  1328500778395463681        Ryan Tull        Tull007       277034700
#
#   Twitter User Location URL in Bio  \
# 0                             None
#
#                                          Twitter Bio  User Verified Status  \
# 0  Proud Democrat, will work w/ anyone for a bett...                 False
#
#    Users Following Count  Number users this account is following  \
# 0                    713                                    1559
#
#    Users Number of Likes  Users Tweet Count  Lists Containing User  \
# 0                  47156             101195                     49
#
#   Account Created Time                                  Profile Image URL  \
# 0  2011-04-04 15:31:34  https://pbs.twimg.com/profile_images/128815390...
#
#    User Default Profile  User Default Profile Image
# 0                 False                       False
